# %%
from pyjsf import JSF
from datetime import datetime

sd = datetime(2016, 9, 21)
ed = datetime(2016, 9, 21)

myJSF = JSF(sd, ed)

# %%
df = myJSF.pcsl()
df.head(10)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>決済日</th>
#       <th>銘柄名</th>
#       <th>市場区分</th>
#       <th>決算事由</th>
#       <th>決算等</th>
#       <th>貸借値段（円）</th>
#       <th>貸株超過株数（株・口）</th>
#       <th>最高料率（円）</th>
#       <th>当日品貸料率（円）</th>
#       <th>当日品貸日数</th>
#       <th>前日品貸料率（円）</th>
#       <th>備考</th>
#       <th>規制</th>
#     </tr>
#     <tr>
#       <th>貸借申込日</th>
#       <th>コード</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="61" valign="top">2016-09-21</th>
#       <th>1301</th>
#       <td>2016-09-27</td>
#       <td>極洋</td>
#       <td>東証</td>
#       <td>権利</td>
#       <td>20160930</td>
#       <td>272</td>
# ...

# %%
df = myJSF.balance()
df.head(10)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>銘柄名</th>
#       <th>市場区分</th>
#       <th>融資新規</th>
#       <th>融資返済</th>
#       <th>融資残高</th>
#       <th>貸株新規</th>
#       <th>貸株返済</th>
#       <th>貸株残高</th>
#       <th>差引残高</th>
#       <th>差引前日比</th>
#     </tr>
#     <tr>
#       <th>申込日</th>
#       <th>コード</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="61" valign="top">2016-09-21</th>
#       <th>1301</th>
#       <td>極洋</td>
#       <td>東証</td>
#       <td>4000</td>
#       <td>0</td>
#       <td>58000</td>
#       <td>7000</td>
#       <td>12000</td>
#       <td>213000</td>
#       <td>-155000</td>
#       <td>9000</td>
#     </tr>
#     <tr>
#       <th>1305</th>
# ...
